# %% [markdown]
# ## 1. Clean your Datasets
#
# For the first part of your project, you will apply the same data cleaning steps to your "data/control.txt" and "data/treatment.txt" files. By the end of this step, you should have two lists of floats that match the numbers you have in each respective file.
#
# You will implement your `clean_data` function in your `cleaner.py` module and import the module in the code-block below.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# TODO: import all the packages that you will need for this notebook here
import matplotlib.pyplot as plt
import statistics as stats
import cleaner
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TODO: read your text files into your code using file I/O

control = open("data/control.txt")
treatment = open("data/treatment.txt")

control_data = control.readlines()
treatment_data = treatment.readlines()

# TODO: clean both list objects that you created above using the 'clean_data' function

clean_control = cleaner.clean_data(control_data)
clean_treatment = cleaner.clean_data(treatment_data)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 2. Explore your Datasets
#
# Now that you have your list objects created and cleaned, let's explore the descriptive statistics of these two files and make subsequent observations on our data.

# %%
# TODO: Calculate the standard deviation of both the control and treatment group

stdev_control = round(stats.stdev(clean_control), 3)
stdev_treatment = round(stats.stdev(clean_treatment), 3)

# TODO: print your findings
print("standard deviation:\n", "control: ", stdev_control, "\n", "treatment: ", stdev_treatment)
# Out:
# standard deviation:
#  control:  3.262
#  treatment:  2.086
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TODO: Calculate the mean of both the control and treatment group

mean_control = round(stats.mean(clean_control), 3)
mean_treatment = round(stats.mean(clean_treatment), 3)

# TODO: print your findings
print("average:\n", "control: ", mean_control, "\n", "treatment: ", mean_treatment)
# Out:
# average:
#  control:  12.451
#  treatment:  16.797
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TODO: Are there any outliers in your control group? (use 2 * stdev to find these outliers)

outliers_control = [x for x in clean_control if abs(x - mean_control) > (2 * stdev_control)]

print(outliers_control)
# Out:
# [5.92, 4.36, 4.21, 20.2, 3.69, 3.83, 21.21, 5.07, 4.87, 5.28, 5.75, 20.18, 20.95, 4.12, 19.21, 5.51, 4.01, 20.57, 20.72, 3.71]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TODO: Are there any outliers in your treatment group?

outliers_treatment = [x for x in clean_treatment if abs(x - mean_treatment) > (2 * stdev_treatment)]

print(outliers_treatment)
# Out:
# [21.17, 10.34, 21.07, 11.54, 21.66, 22.11, 12.02, 12.41, 11.35, 22.85, 21.49, 11.99, 21.57, 21.76, 12.54, 12.53, 12.34, 12.32, 21.42, 10.33]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 3. Create Data Visualizations
#
# For this final step, generate data visualizations to view the dispersion of both of your groups.
#
# Make sure that the two visualizations you create are on the same figure.

# %%
# TODO: create a data visualization to view differences in dispersion and mean

plt.figure(figsize=(8, 6))

data_to_plot = [clean_control, clean_treatment]


plt.boxplot(data_to_plot, labels=['Control', 'Treatment'], showmeans=True)

plt.title('Dispersion and Mean Comparison')
plt.ylabel('Viewing Time (Minutes)')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
# Out:
# C:\Users\nbhun\AppData\Local\Temp\ipykernel_17372\648802540.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_to_plot, labels=['Control', 'Treatment'], showmeans=True)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 4. Your Data Findings
#
# What did you discover about your two datasets? Which group has the highest viewing time? What would you want to investigate next?

# %% [markdown]
# Based on these findings, the redesign of the slide format had a significant and measurable impact on employee engagement.
#
# * The control group shows much higher dispersiona and volatility in viewing times, with values ranging from roughly 3.7  to 21.2 minutes. In contrast, the treatment group is more consistent, with the majority of users clustered tightly around the average.
#
# * The control group contains significant outliers on both the low and high ends, suggesting that the original 50-word slide format either led to rapid disengagement or required excessive time for some to digest.
#
# * The treatment group has a much higher floor. While the lowest viewing time the control group was under 4 minutes, the treatment group rarely dipped below 10-12 minutes. This may suggest that the new format is more effective at maintaining a baseline level of attention.
#
# * The treatment group has a significantly higher average viewing time and its overall distribution is shifted upward.
#
# While the treatment group stayed on the slides longer, that doesn't always mean better. I would want to cross-reference these times with quiz scores or a comprehension assessment to ensure they weren't just spending more time because the 15-word slides were too vague.
#
# I would also investigate where in the presentation users in the control group stopped watching. This would help determine if the 50-word slides caused any cognitive fatigue at a specific point in the workshop.
